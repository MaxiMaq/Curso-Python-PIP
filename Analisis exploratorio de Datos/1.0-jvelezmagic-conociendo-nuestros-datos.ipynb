# %% [markdown]
# # Conociendo nuestros datos de pingüinos. 🗺🧭🐧

# %% [markdown]
# ## Instalar librerías necesarias

# %% [markdown]
# ```
# !pip install --upgrade pip
# ```
# ```
# !pip install palmerpenguins==0.1.4 numpy==1.23.4 pandas==1.5.1 seaborn==0.12.1 matplotlib==3.6.0 empiricaldist==0.6.7 statsmodels==0.13.5 scikit-learn==1.1.2 pyjanitor==0.23.1 session-info
# ```

# %% [markdown]
# ## Importar librerías

# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import palmerpenguins
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss
import session_info

# %% [markdown]
# ## Establecer apariencia general de los gráficos

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %% [markdown]
# ## Cargar los datos

# %% [markdown]
# ### Utilizando el paquete `palmerpenguins`

# %% [markdown]
# #### Datos crudos

# %%
raw_penguins_df= palmerpenguins.load_penguins_raw()
raw_penguins_df
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# 0    Anvers  Torgersen  Adult, 1 Egg Stage          N1A1               Yes
# 1    Anvers  Torgersen  Adult, 1 Egg Stage          N1A2               Yes
# 2    Anvers  Torgersen  Adult, 1 Egg Stage          N2A1               Yes
# 3    Anvers  Torgersen  Adult, 1 Egg Stage          N2A2               Yes
# 4    Anvers  Torgersen  Adult, 1 Egg Stage          N3A1               Yes
# ..      ...        ...                 ...           ...               ...
# 339  Anvers      Dream  Adult, 1 Egg Stage         N98A2               Yes
# 340  Anvers      Dream  Adult, 1 Egg Stage         N99A1                No
# 341  Anvers      Dream  Adult, 1 Egg Stage         N99A2                No
# 342  Anvers      Dream  Adult, 1 Egg Stage        N100A1               Yes
# 343  Anvers      Dream  Adult, 1 Egg Stage        N100A2               Yes
#
#        Date Egg  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    2007-11-11                39.1               18.7                181.0
# 1    2007-11-11                39.5               17.4                186.0
# 2    2007-11-16                40.3               18.0                195.0
# 3    2007-11-16                 NaN                NaN                  NaN
# 4    2007-11-16                36.7               19.3                193.0
# ..          ...                 ...                ...                  ...
# 339  2009-11-19                55.8               19.8                207.0
# 340  2009-11-21                43.5               18.1                202.0
# 341  2009-11-21                49.6               18.2                193.0
# 342  2009-11-21                50.8               19.0                210.0
# 343  2009-11-21                50.2               18.7                198.0
#
#      Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0           3750.0    MALE                NaN                NaN
# 1           3800.0  FEMALE            8.94956          -24.69454
# 2           3250.0  FEMALE            8.36821          -25.33302
# 3              NaN     NaN                NaN                NaN
# 4           3450.0  FEMALE            8.76651          -25.32426
# ..             ...     ...                ...                ...
# 339         4000.0    MALE            9.70465          -24.53494
# 340         3400.0  FEMALE            9.37608          -24.40753
# 341         3775.0    MALE            9.46180          -24.70615
# 342         4100.0    MALE            9.98044          -24.68741
# 343         3775.0  FEMALE            9.39305          -24.25255
#
#                                   Comments
# 0           Not enough blood for isotopes.
# 1                                      NaN
# 2                                      NaN
# 3                       Adult not sampled.
# 4                                      NaN
# ..                                     ...
# 339                                    NaN
# 340  Nest never observed with full clutch.
# 341  Nest never observed with full clutch.
# 342                                    NaN
# 343                                    NaN
#
# [344 rows x 17 columns]

# %% [markdown]
# #### Datos previamente procesados

# %%
preprocess_penguins_df = palmerpenguins.load_penguins()
preprocess_penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [344 rows x 8 columns]

# %% [markdown]
# ### Utilizando los conjuntos de datos de `seaborn`

# %%
sns.load_dataset('penguins')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# ### Utilizando la interfaz de `Deepnote`
#
# Links de importación de datos:
#
# - [Conjunto de datos crudos](https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins_raw.csv).
# - [Conjunto de datos previamente procesados](https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv).

# %%
preprocess_penguin_df = pd.read_csv('penguins.csv')
preprocess_penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [344 rows x 8 columns]

# %% [markdown]
# # Colecta y validación de datos

# %% [markdown]
# ## ¿Qué tipo de dato son las variables del conjunto de datos?

# %%
preprocess_penguins_df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %% [markdown]
# ## ¿Cuántas variables de cada tipo de dato tenemos en el conjunto de datos?

# %%
(
    preprocess_penguins_df
    .dtypes
    .value_counts()
)
# Out:
# float64    4
# object     3
# int64      1
# dtype: int64

# %% [markdown]
# ## ¿Cuántas variables y observaciones tenemos en el conjunto de datos?

# %%
preprocess_penguins_df.shape
# Out:
# (344, 8)

# %% [markdown]
# ## ¿Existen valores nulos explícitos en el conjunto de datos?

# %%
(
    preprocess_penguins_df
    .isnull()
    .any()
)
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# year                 False
# dtype: bool

# %% [markdown]
# ## De tener observaciones con valores nulos, ¿cuántas tenemos por cada variable?

# %%
(
    preprocess_penguins_df
    .isnull()
    .sum()
)
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# ## ¿Cuántos valores nulos tenemos en total en el conjunto de datos?

# %%
(
    preprocess_penguins_df
    .isnull()
    .sum()
    .sum()
)
# Out:
# 19

# %% [markdown]
# ## ¿Cuál es la proporción de valores nulos por cada variable?

# %%
(
    preprocess_penguins_df
    .isnull()
    .melt()
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                y='variable',
                hue='value',
                multiple='fill'
            )
        )
    )
)

# %% [markdown]
# ## ¿Cómo podemos visualizar los valores nulos en todo el conjunto de datos?

# %%
(
    preprocess_penguin_df
    .isnull()
    .transpose()
    .pipe(
        lambda df: (
            sns.heatmap(
                data=df
            )
        )
    )
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## ¿Cuántas observaciones perdemos si eliminamos los datos faltantes?

# %%
processed_penguins_df = (
    preprocess_penguin_df
    .dropna()
)
processed_penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 4         3450.0  female  2007
# 5         3650.0    male  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [333 rows x 8 columns]

# %% [markdown]
# # Conteos y proporciones

# %% [markdown]
# ## Preludio: ¿Qué estadísticos describen el conjunto de datos?

# %% [markdown]
# ### Todas las variables

# %%
processed_penguins_df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      333     333      333.000000     333.000000         333.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       146     163             NaN            NaN                NaN
# mean       NaN     NaN       43.992793      17.164865         200.966967
# std        NaN     NaN        5.468668       1.969235          14.015765
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.500000      15.600000         190.000000
# 50%        NaN     NaN       44.500000      17.300000         197.000000
# 75%        NaN     NaN       48.600000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex         year
# count    333.000000   333   333.000000
# unique          NaN     2          NaN
# top             NaN  male          NaN
# freq            NaN   168          NaN
# mean    4207.057057   NaN  2008.042042
# std      805.215802   NaN     0.812944
# min     2700.000000   NaN  2007.000000
# 25%     3550.000000   NaN  2007.000000
# 50%     4050.000000   NaN  2008.000000
# 75%     4775.000000   NaN  2009.000000
# max     6300.000000   NaN  2009.000000

# %% [markdown]
# ### Solo las numéricas

# %%
processed_penguins_df.describe(include=[np.number])
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   333.000000
# mean   2008.042042
# std       0.812944
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# ### Solo categóricas - 1

# %%
processed_penguins_df.describe(include=object)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# ### Solo categóricas - 2

# %%
(
    processed_penguins_df
    .astype({
        'species' : 'category',
        'island' : 'category',
        'sex' : 'category'
    })
)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 4         3450.0  female  2007
# 5         3650.0    male  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [333 rows x 8 columns]

# %% [markdown]
# ## ¿Cómo visualizar los conteos?

# %% [markdown]
# ### Pandas

# %%
(
    processed_penguins_df
    .species
    .value_counts()
    .plot(
        kind='bar'
    )
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Seaborn

# %%
sns.catplot(
    data=processed_penguins_df,
    x='species',
    kind='count',
    palette=penguin_color
)

# %%
(
    processed_penguins_df
    .value_counts('species', sort=True)
    .reset_index(name='count')
    .pipe(
        lambda df: (
            sns.barplot(
                data=df,
                x='species',
                y='count',
                palette= penguin_color
            )
        )
    )
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %% [markdown]
# ### ¿Cómo visualizar las proporciones?

# %%
(
    processed_penguins_df
    .add_column('x','')
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x='x',
                hue='species',
                multiple='fill',
                palette=penguin_color
            )
        )
    )
)

# %% [markdown]
# # Medidas de tendencia central

# %% [markdown]
# ## Media o promedio

# %%
processed_penguins_df.bill_depth_mm.mean()
# Out:
# 17.164864864864867

# %%
np.mean(processed_penguins_df.bill_depth_mm)
# Out:
# 17.164864864864867

# %%
processed_penguins_df.mean()
# Out:
# /tmp/ipykernel_228/1618060137.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean()
# bill_length_mm         43.992793
# bill_depth_mm          17.164865
# flipper_length_mm     200.966967
# body_mass_g          4207.057057
# year                 2008.042042
# dtype: float64

# %% [markdown]
# ## Mediana

# %%
processed_penguins_df.median()
# Out:
# /tmp/ipykernel_228/3242987746.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.median()
# bill_length_mm         44.5
# bill_depth_mm          17.3
# flipper_length_mm     197.0
# body_mass_g          4050.0
# year                 2008.0
# dtype: float64

# %% [markdown]
# ## Moda

# %%
processed_penguins_df.mode()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            41.1           17.0              190.0
#
#    body_mass_g   sex  year
# 0       3800.0  male  2009

# %%
processed_penguins_df.describe(include=object)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# # Medidas de dispersión

# %% [markdown]
# ## ¿Cuál es el valor máximo de las variables?

# %%
processed_penguins_df.max(numeric_only=True)
# Out:
# bill_length_mm         59.6
# bill_depth_mm          21.5
# flipper_length_mm     231.0
# body_mass_g          6300.0
# year                 2009.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el valor mínimo de las variables?

# %%
processed_penguins_df.min(numeric_only=True)
# Out:
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# year                 2007.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el rango de las variables?

# %%
processed_penguins_df.max(numeric_only=True) - processed_penguins_df.min(numeric_only=True)
# Out:
# bill_length_mm         27.5
# bill_depth_mm           8.4
# flipper_length_mm      59.0
# body_mass_g          3600.0
# year                    2.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es la desviación estándar de las variables?

# %%
processed_penguins_df.std()
# Out:
# /tmp/ipykernel_228/4261057176.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.std()
# bill_length_mm         5.468668
# bill_depth_mm          1.969235
# flipper_length_mm     14.015765
# body_mass_g          805.215802
# year                   0.812944
# dtype: float64

# %%
processed_penguins_df.mean() - processed_penguins_df.std()
# Out:
# /tmp/ipykernel_228/1336703272.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean() - processed_penguins_df.std()
# /tmp/ipykernel_228/1336703272.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean() - processed_penguins_df.std()
# bill_length_mm         38.524124
# bill_depth_mm          15.195629
# flipper_length_mm     186.951202
# body_mass_g          3401.841255
# year                 2007.229098
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el rango intercuartílico?

# %%
processed_penguins_df.quantile(0.75)
# Out:
# /tmp/ipykernel_228/3609120765.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.quantile(0.75)
# bill_length_mm         48.6
# bill_depth_mm          18.7
# flipper_length_mm     213.0
# body_mass_g          4775.0
# year                 2009.0
# Name: 0.75, dtype: float64

# %%
processed_penguins_df.quantile(0.25)
# Out:
# /tmp/ipykernel_228/2653252021.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.quantile(0.25)
# bill_length_mm         39.5
# bill_depth_mm          15.6
# flipper_length_mm     190.0
# body_mass_g          3550.0
# year                 2007.0
# Name: 0.25, dtype: float64

# %%
processed_penguins_df.quantile(0.75) - processed_penguins_df.quantile(0.25)
# Out:
# /tmp/ipykernel_228/1337602098.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.quantile(0.75) - processed_penguins_df.quantile(0.25)
# bill_length_mm          9.1
# bill_depth_mm           3.1
# flipper_length_mm      23.0
# body_mass_g          1225.0
# year                    2.0
# dtype: float64

# %%
(
    processed_penguins_df
    .quantile(q=[0.75,0.50,0.25])
    .transpose()
    .rename_axis('variable')
    .reset_index()
    .assign(
        iqr=lambda df: df[0.75] - df[0.25]
    )
)
# Out:
# /tmp/ipykernel_228/836226389.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df
#             variable    0.75     0.5    0.25     iqr
# 0     bill_length_mm    48.6    44.5    39.5     9.1
# 1      bill_depth_mm    18.7    17.3    15.6     3.1
# 2  flipper_length_mm   213.0   197.0   190.0    23.0
# 3        body_mass_g  4775.0  4050.0  3550.0  1225.0
# 4               year  2009.0  2008.0  2007.0     2.0

# %% [markdown]
# ## ¿Cómo puedo visualizar la distribución de una variable?

# %% [markdown]
# ### Histograma

# %%
sns.histplot(
    data=processed_penguins_df,
    x='flipper_length_mm'
)

plt.axvline(
    x=processed_penguins_df.flipper_length_mm.mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)

# %% [markdown]
# ### Diagrama de caja / boxplot

# %%
sns.boxplot(
    data=processed_penguins_df,
    x='flipper_length_mm'
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm'>

# %% [markdown]
# ### Limitaciones

# %%
def freedman_diaconis_bindwidth(x: pd.Series) -> float:
    """Find optimal bindwidth using Freedman-Diaconis rule."""

    IQR = x.quantile(0.75) - x.quantile(0.25)
    N = x.size

    return 2 * IQR / N ** (1 / 3)

# %%
sns.histplot(
    data=processed_penguins_df,
    x='flipper_length_mm',
    binwidth=4
)

plt.axvline(
    x=processed_penguins_df.flipper_length_mm.mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)

# %% [markdown]
# # Distribuciones: PMFs, CDFs y PDFs

# %% [markdown]
# ## Funciones de probabilidad de masas (PMFs)

# %% [markdown]
# ### Utilizando `seaborn`

# %%
sns.histplot(
    data=processed_penguins_df,
    x='flipper_length_mm',
    binwidth=1,
    stat='probability'
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Probability'>

# %% [markdown]
# ### Utilizando `empiricaldist`

# %%
pmf_flipper_length_mm = empiricaldist.Pmf.from_seq(
    processed_penguins_df.flipper_length_mm,
    normalize=True
)

# %%
pmf_flipper_length_mm.bar()

# %%
pmf_flipper_length_mm(190)
# Out:
# 0.06306306306306306

# %%
processed_penguins_df.flipper_length_mm.max()
# Out:
# 231.0

# %% [markdown]
# ## Funciones empirícas de probabilidad acumulada (ECDFs)

# %% [markdown]
# ### Utilizando `seaborn`

# %%
sns.ecdfplot(
    data=processed_penguins_df,
    x='flipper_length_mm'
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# ### Utilizando `empiricaldist`

# %%
cdf_flipper_length_mm = empiricaldist.Cdf.from_seq(
    processed_penguins_df.flipper_length_mm,
    normalize=True
)

# %%
cdf_flipper_length_mm.plot()

q=200
p = cdf_flipper_length_mm(q)

print(q, p)
# Out:
# 200 0.5675675675675675

# %% [markdown]
# ### Comparando distribuciones

# %%
sns.ecdfplot(
    data=processed_penguins_df,
    x='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# ## Funciones de densidad de probabilidad

# %%
sns.kdeplot(
    data=processed_penguins_df,
    x='flipper_length_mm',
    bw_method = 0.1
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Density'>

# %%
stats = processed_penguins_df.body_mass_g.describe()
stats
# Out:
# count     333.000000
# mean     4207.057057
# std       805.215802
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4775.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
xs = np.linspace(stats['min'], stats['max'])
ys = scipy.stats.norm(stats['mean'], stats['std']).cdf(xs)

plt.plot(xs, ys, color='black', linestyle='dashed')

empiricaldist.Cdf.from_seq(
    processed_penguins_df.body_mass_g,
    normalize=True
).plot()
# Out:
# <AxesSubplot: >

# %%
xs = np.linspace(stats['min'], stats['max'])
ys = scipy.stats.norm(stats['mean'], stats['std']).pdf(xs)

plt.plot(xs, ys, color='black', linestyle='dashed')

sns.kdeplot(
    data=processed_penguins_df,
    x='body_mass_g'
)
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# # Ley de los Grandes Números y Teorema del Límite Central

# %% [markdown]
# ## Ley de los Grandes Números

# %%
dice = empiricaldist.Pmf.from_seq([1, 2, 3 ,4, 5, 6])
dice.bar()

# %%
for sample_size in (1e2, 1e3, 1e4):
    sample_size = int(sample_size)
    values = dice.sample(sample_size)
    sample_pmf = empiricaldist.Pmf.from_seq(values)
    plt.figure(figsize=(5,5))
    sample_pmf.bar()
    plt.axhline(y=1/6, color='red', linestyle='dashed')
    plt.ylim([0, 0.50])
    plt.title(f'Sample size: {sample_size}')

# %% [markdown]
# ## Teorema del Límite Central

# %%
processed_penguins_df.sex.value_counts(normalize=True)
# Out:
# male      0.504505
# female    0.495495
# Name: sex, dtype: float64

# %%
sex_numeric = processed_penguins_df.sex.replace(['male' , 'female'], [1, 0])

# %% [markdown]
# # Estableciendo relaciones: Gráfica de puntos

# %%
sns.scatterplot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    alpha=1/1,
    s=100
)
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.displot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True
)

# %%
sns.displot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True,
    kind='kde'
)

# %%
sns.jointplot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm'
)

# %% [markdown]
# # Estableciendo relaciones: Gráficos de violín y boxplots

# %%
sns.scatterplot(
    data=processed_penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.stripplot(
    data=processed_penguins_df,
    x='species',
    y='flipper_length_mm',
    palette=penguin_color
)
# Out:
# /tmp/ipykernel_228/826111948.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
ax = sns.boxplot(
    data=processed_penguins_df,
    x='flipper_length_mm',
    y='species',
    palette=penguin_color
)

ax = sns.stripplot(
    data=processed_penguins_df,
    x='flipper_length_mm',
    y='species',
    color='.3'
)

# %%
ax = sns.violinplot(
    data=processed_penguins_df,
    x='species',
    y='flipper_length_mm',
    color='.7'
)

ax = sns.stripplot(
    data=processed_penguins_df,
    x='species',
    y='flipper_length_mm',
    palette=penguin_color
)
# Out:
# /tmp/ipykernel_228/171702021.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   ax = sns.stripplot(

# %%
sns.swarmplot(
    data=processed_penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.jointplot(
    data=processed_penguins_df,
    x='island',
    y='body_mass_g',
    hue='species'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_228/3630601111.py in <module>
# ----> 1 sns.jointplot(
#       2     data=processed_penguins_df,
#       3     x='island',
#       4     y='body_mass_g',
#       5     hue='species'
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2263
#    2264         marginal_kws.setdefault("color", color)
# -> 2265         grid.plot_marginals(marg_func, **marginal_kws)
#    2266
#    2267     elif kind.startswith("hist"):
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in plot_marginals(self, func, **kwargs)
#    1875
#    1876         if seaborn_func:
# -> 1877             func(x=self.x, ax=self.ax_marg_x, **kwargs)
#    1878         else:
#    1879             plt.sca(self.ax_marg_x)
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1693         ax = plt.gca()
#    1694
# -> 1695     p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1696
#    1697     method = ax.fill_between if fill else ax.plot
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py in _attach(self, obj, allowed_types, log_scale)
#    1209                     f"{allowed_types} is required"
#    1210                 )
# -> 1211                 raise TypeError(err)
#    1212
#    1213         # -- Get axis objects for each row in plot_data for type conversions and scaling
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %% [markdown]
# # Estableciendo relaciones: Matrices de correlación

# %% [markdown]
# ## ¿Existe una correlación lineal entre alguna de nuestras variables?

# %%
processed_penguins_df.corr()
# Out:
# /tmp/ipykernel_260/4090656914.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
# year                     0.032657      -0.048182           0.151068
#
#                    body_mass_g      year
# bill_length_mm        0.589451  0.032657
# bill_depth_mm        -0.472016 -0.048182
# flipper_length_mm     0.872979  0.151068
# body_mass_g           1.000000  0.021862
# year                  0.021862  1.000000

# %% [markdown]
# ## ¿Cómo puedo visualizar los coeficientes de correlación?

# %%
sns.heatmap(
    data=processed_penguins_df.corr(),
    cmap=sns.diverging_palette(20,230, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True
)
# Out:
# /tmp/ipykernel_260/1712331342.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=processed_penguins_df.corr(),
# <AxesSubplot: >

# %%
sns.clustermap(
    data=processed_penguins_df.corr(),
    cmap=sns.diverging_palette(20,230, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True
)
# Out:
# /tmp/ipykernel_260/468032030.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=processed_penguins_df.corr(),

# %% [markdown]
# ## ¿Cómo podría representar una variable categórica como númerica discreta?

# %%
processed_penguins_df = (
    processed_penguins_df
    .assign(
        numeric_sex=lambda df: df.sex.replace(['female', 'male'], [0, 1])
    )
)

# %%
sns.clustermap(
    data=processed_penguins_df.corr(),
    cmap=sns.diverging_palette(20,230, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True
)
# Out:
# /tmp/ipykernel_260/468032030.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=processed_penguins_df.corr(),

# %% [markdown]
# ## ¿Cuál es una limitante de los coeficientes de correlación lineal?

# %% [markdown]
# ### Solo nos ayuda a determinar la posible existencia de una correlación lineal; sin embargo, su ausenecia no significa que no exista otro tipo de correlación

# %%
x = np.linspace(-100, 100, 100)
y= x**2
y += np.random.normal(0, 1000, x.size)

sns.scatterplot(
    x=x, y=y
)

np.corrcoef(x,y)
# Out:
# array([[1.       , 0.0114427],
#        [0.0114427, 1.       ]])

# %%
x = np.linspace(-100, 100, 100)
y= x**3
y += np.random.normal(0, 1000, x.size)

sns.scatterplot(
    x=x, y=y
)

np.corrcoef(x,y)
# Out:
# array([[1.        , 0.91655906],
#        [0.91655906, 1.        ]])

# %%
sns.scatterplot(
    data=processed_penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm'
)
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# ### El coeficiente de correlación no nos habla del impacto de la relación

# %% [markdown]
# # Estableciendo relaciones: Análisis de regresión simple

# %%
res_1 = scipy.stats.linregress(x=x1, y=y1)
res_2 = scipy.stats.linregress(x=x2, y=y2)

print(res_1, res_2, sep='\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_260/2353951113.py in <module>
# ----> 1 res_1 = scipy.stats.linregress(x=x1, y=y1)
#       2 res_2 = scipy.stats.linregress(x=x2, y=y2)
#       3
#       4 print(res_1, res_2, sep='\n')
#
# NameError: name 'x1' is not defined

# %%
sns.scatterplot(x=x1, y=y1)

fx1 = np.array([x1.min(), x1.max()])
fy1 = r1.intercept + r1.slope * fx1

plt.plot(fx1, fy1)


sns.scatterplot(x=x2, y=y2)

fx2 = np.array([x2.min(), x2.max()])
fy2 = r2.intercept + r2.slope * fx2

plt.plot(fx2, fy2)

plt.legend(["1", "1","2","2"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_260/1823545695.py in <module>
# ----> 1 sns.scatterplot(x=x1, y=y1)
#       2
#       3 fx1 = np.array([x1.min(), x1.max()])
#       4 fy1 = r1.intercept + r1.slope * fx1
#       5
#
# NameError: name 'x1' is not defined

# %%
sns.scatterplot(processed, x="bill_length_mm", y="bill_depth_mm")

res_penguins = scipy.stats.linregress(x=processed.bill_length_mm, y=processed.bill_depth_mm)

print(res_penguins)

fx1 = np.array([processed.bill_length_mm.min(), processed.bill_length_mm.max()])
fy1 = res_penguins.intercept + res_penguins.slope * fx1

plt.plot(fx1,fy1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_260/1815879045.py in <module>
# ----> 1 sns.scatterplot(processed, x="bill_length_mm", y="bill_depth_mm")
#       2
#       3 res_penguins = scipy.stats.linregress(x=processed.bill_length_mm, y=processed.bill_depth_mm)
#       4
#       5 print(res_penguins)
#
# NameError: name 'processed' is not defined

# %% [markdown]
# # Limitaciones del análisis de regresión simple

# %% [markdown]
# ## La regresión lineal simple no es simétrica

# %%
x = processed_penguins_df.bill_length_mm
y = processed_penguins_df.bill_depth_mm

res_x_y = scipy.stats.linregress(x=x, y=y)
res_y_x = scipy.stats.linregress(x=y, y=x)

print(res_x_y, res_y_x, sep='\n')
# Out:
# LinregressResult(slope=-0.08232675339862275, intercept=20.786648668433827, rvalue=-0.22862563591302898, pvalue=2.5282897209443435e-05, stderr=0.019268346735778864, intercept_stderr=0.8541730787409804)
# LinregressResult(slope=-0.6349051704195019, intercept=54.89085424504755, rvalue=-0.22862563591302898, pvalue=2.5282897209443435e-05, stderr=0.1485977821662331, intercept_stderr=2.5673415135382553)

# %%
sns.scatterplot(
    x=x,
    y=y
)

fx_1= np.array([x.min(), x.max()])
fy_1= res_x_y.intercept + res_x_y.slope * fx_1

plt.plot(fx_1, fy_1)

# %%
sns.scatterplot(
    x=y,
    y=x
)

fx_2= np.array([y.min(), y.max()])
fy_2= res_y_x.intercept + res_y_x.slope * fx_2

plt.plot(fx_2, fy_2)

# %% [markdown]
# ## La regresión no nos dice nada sobre la causalidad, pero existen herramientas para separar las relaciones entre múltiples variables

# %%
(
    smf.ols(
        formula='bill_length_mm ~ bill_depth_mm ',
        data=processed_penguins_df
    )
    .fit()
    .params
)
# Out:
# Intercept        54.890854
# bill_depth_mm    -0.634905
# dtype: float64

# %%
(
    smf.ols(
        formula='bill_depth_mm ~ bill_length_mm',
        data=processed_penguins_df
    )
    .fit()
    .params
)
# Out:
# Intercept         20.786649
# bill_length_mm    -0.082327
# dtype: float64

# %% [markdown]
# # Análisis de regresión múltiple

# %% [markdown]
# ## Olvidé mi báscula para pesar a los pingüinos, ¿cuál sería la mejor forma de capturar ese dato?

# %% [markdown]
# ### Creando modelos

# %% [markdown]
# #### Modelo 1

# %%
model_1 = (
    smf.ols(
        formula='body_mass_g ~ bill_length_mm',
        data=processed_penguins_df
    )
    .fit()
)

model_1.summary()  #descripcion del modelo
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     176.2
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):           1.54e-32
# Time:                        11:58:07   Log-Likelihood:                -2629.1
# No. Observations:                 333   AIC:                             5262.
# Df Residuals:                     331   BIC:                             5270.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        388.8452    289.817      1.342      0.181    -181.271     958.961
# bill_length_mm    86.7918      6.538     13.276      0.000      73.931      99.652
# ==============================================================================
# Omnibus:                        6.141   Durbin-Watson:                   0.849
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                4.899
# Skew:                          -0.197   Prob(JB):                       0.0864
# Kurtosis:                       2.555   Cond. No.                         360.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Modelo 2

# %%
model_2 = (
    smf.ols(
        formula='body_mass_g ~ bill_length_mm + bill_depth_mm',
        data=processed_penguins_df
    )
    .fit()
)

model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     144.8
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):           7.04e-46
# Time:                        11:58:36   Log-Likelihood:                -2595.2
# No. Observations:                 333   AIC:                             5196.
# Df Residuals:                     330   BIC:                             5208.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       3413.4519    437.911      7.795      0.000    2552.002    4274.902
# bill_length_mm    74.8126      6.076     12.313      0.000      62.860      86.765
# bill_depth_mm   -145.5072     16.873     -8.624      0.000    -178.699    -112.315
# ==============================================================================
# Omnibus:                        2.839   Durbin-Watson:                   1.798
# Prob(Omnibus):                  0.242   Jarque-Bera (JB):                2.175
# Skew:                          -0.000   Prob(JB):                        0.337
# Kurtosis:                       2.604   Cond. No.                         644.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Modelo 3

# %%
model_3 = (
    smf.ols(
        formula='body_mass_g ~ bill_length_mm + bill_depth_mm + flipper_length_mm',
        data=processed_penguins_df
    )
    .fit()
)

model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     354.9
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):          9.26e-103
# Time:                        12:00:05   Log-Likelihood:                -2459.8
# No. Observations:                 333   AIC:                             4928.
# Df Residuals:                     329   BIC:                             4943.
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -6445.4760    566.130    -11.385      0.000   -7559.167   -5331.785
# bill_length_mm        3.2929      5.366      0.614      0.540      -7.263      13.849
# bill_depth_mm        17.8364     13.826      1.290      0.198      -9.362      45.035
# flipper_length_mm    50.7621      2.497     20.327      0.000      45.850      55.675
# ==============================================================================
# Omnibus:                        5.596   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                5.469
# Skew:                           0.312   Prob(JB):                       0.0649
# Kurtosis:                       3.068   Cond. No.                     5.44e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Modelo 4

# %%
model_4 = (
    smf.ols(
        formula='body_mass_g ~ bill_length_mm + bill_depth_mm + flipper_length_mm + C(sex)',
        data=processed_penguins_df
    )
    .fit()
)

model_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     381.3
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):          6.28e-122
# Time:                        12:00:14   Log-Likelihood:                -2411.8
# No. Observations:                 333   AIC:                             4834.
# Df Residuals:                     328   BIC:                             4853.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -2288.4650    631.580     -3.623      0.000   -3530.924   -1046.006
# C(sex)[T.male]      541.0285     51.710     10.463      0.000     439.304     642.753
# bill_length_mm       -2.3287      4.684     -0.497      0.619     -11.544       6.886
# bill_depth_mm       -86.0882     15.570     -5.529      0.000    -116.718     -55.459
# flipper_length_mm    38.8258      2.448     15.862      0.000      34.011      43.641
# ==============================================================================
# Omnibus:                        2.598   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.273   Jarque-Bera (JB):                2.125
# Skew:                           0.062   Prob(JB):                        0.346
# Kurtosis:                       2.629   Cond. No.                     7.01e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Modelo 5

# %%
model_5 = (
    smf.ols(
        formula='body_mass_g ~ flipper_length_mm + C(sex)',
        data=processed_penguins_df
    )
    .fit()
)

model_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     684.8
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):          3.53e-118
# Time:                        12:01:20   Log-Likelihood:                -2427.2
# No. Observations:                 333   AIC:                             4860.
# Df Residuals:                     330   BIC:                             4872.
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -5410.3002    285.798    -18.931      0.000   -5972.515   -4848.085
# C(sex)[T.male]      347.8503     40.342      8.623      0.000     268.491     427.209
# flipper_length_mm    46.9822      1.441     32.598      0.000      44.147      49.817
# ==============================================================================
# Omnibus:                        0.262   Durbin-Watson:                   1.710
# Prob(Omnibus):                  0.877   Jarque-Bera (JB):                0.376
# Skew:                           0.051   Prob(JB):                        0.829
# Kurtosis:                       2.870   Cond. No.                     2.95e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.95e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Visualizando resultados

# %% [markdown]
# #### Creación de tabla de resultados

# %%
models_result = pd.DataFrame(
    dict(
        actual_value = processed_penguins_df.body_mass_g,
        prediction_model_1 = model_1.predict(),
        prediction_model_2 = model_2.predict(),
        prediction_model_3 = model_3.predict(),
        prediction_model_4 = model_4.predict(),
        prediction_model_5 = model_5.predict(),
        species=processed_penguins_df.species,
        sex=processed_penguins_df.sex
    )
)

models_result
# Out:
#      actual_value  prediction_model_1  prediction_model_2  prediction_model_3  \
# 0          3750.0         3782.402961         3617.641192         3204.761227
# 1          3800.0         3817.119665         3836.725580         3436.701722
# 2          3250.0         3886.553073         3809.271371         3906.897032
# 4          3450.0         3574.102738         3350.786581         3816.705772
# 5          3650.0         3799.761313         3356.140070         3696.168128
# ..            ...                 ...                 ...                 ...
# 339        4000.0         5231.825347         4706.954140         4599.187485
# 340        3400.0         4164.286703         4034.121055         4274.552753
# 341        3775.0         4693.716437         4475.927353         3839.563668
# 342        4100.0         4797.866549         4449.296758         4720.740455
# 343        3775.0         4745.791493         4448.061337         4104.268240
#
#      prediction_model_4  prediction_model_5    species     sex
# 0           3579.136946         3441.323750     Adelie    male
# 1           3343.220772         3328.384372     Adelie  female
# 2           3639.137335         3751.223949     Adelie  female
# 4           3457.954243         3657.259599     Adelie  female
# 5           3764.536023         3864.163327     Adelie    male
# ..                  ...                 ...        ...     ...
# 339         4455.022405         4662.860306  Chinstrap    male
# 340         3894.857519         4080.099176  Chinstrap  female
# 341         4063.639819         4005.109853  Chinstrap    male
# 342         4652.013882         4803.806832  Chinstrap    male
# 343         3672.299099         3892.170475  Chinstrap  female
#
# [333 rows x 8 columns]

# %% [markdown]
# #### ECDFs

# %%
sns.ecdfplot(
    data=models_result
)
# Out:
# <AxesSubplot: ylabel='Proportion'>

# %%
sns.ecdfplot(
    data=models_result.select_columns(['actual_value', 'prediction_model_5'])
)
# Out:
# <AxesSubplot: ylabel='Proportion'>

# %% [markdown]
# #### PDFs

# %%
sns.kdeplot(
    data=models_result
)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
sns.kdeplot(
    data=models_result,
    cumulative=True #genera curvas suavizadas de tipo acumulativas
)
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# #### ¿Qué pudimos haber encontrado antes de hacer los modelos?

# %%
sns.lmplot(
    data=processed_penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    hue='sex',
    height=10
)

# %% [markdown]
# # Análisis de regresión logística

# %% [markdown]
# ## ¿Podemos crear un modelo que nos ayude a definir si un pingüino es macho o hembra?

# %%
#Modelo logistico de la variable sexo VS longitud de las aletas, ancho del pico, largo del pico, y la isla
smf.logit(
    formula='numeric_sex ~ flipper_length_mm + bill_length_mm + bill_depth_mm + C(island)',
    data=processed_penguins_df
).fit().summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     168         code = compile(expr, source_name, "eval", self.flags, False)
# --> 169         return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'numeric_sex' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# /tmp/ipykernel_260/3212573923.py in <module>
#       1 #Modelo logistico de la variable sexo VS longitud de las aletas, ancho del pico, largo del pico, y la isla
# ----> 2 smf.logit(
#       3     formula='numeric_sex ~ flipper_length_mm + bill_length_mm + bill_depth_mm + C(island)',
#       4     data=processed_penguins_df
#       5 ).fit().summary()
#
# ~/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     198             missing = 'raise'
#     199
# --> 200         tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     201                                   missing=missing)
#     202         ((endog, exog), missing_idx, design_info) = tmp
#
# ~/anaconda3/lib/python3.9/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      61     else:
#      62         if data_util._is_using_pandas(Y, None):
# ---> 63             result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                                NA_action=na_action)
#      65         else:
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307     """
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162     def data_iter_maker():
#     163         return iter([data])
# --> 164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                       NA_action)
#     166     if design_infos is not None:
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64     if isinstance(formula_like, ModelDesc):
#      65         assert isinstance(eval_env, EvalEnvironment)
# ---> 66         return design_matrix_builders([formula_like.lhs_termlist,
#      67                                        formula_like.rhs_termlist],
#      68                                       data_iter_maker,
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     691     # on some data to find out what type of data they return.
#     692     (num_column_counts,
# --> 693      cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/eval.py in eval(self, memorize_state, data)
#     566
#     567     def eval(self, memorize_state, data):
# --> 568         return self._eval(memorize_state["eval_code"],
#     569                           memorize_state,
#     570                           data)
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     549     def _eval(self, code, memorize_state, data):
#     550         inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 551         return call_and_wrap_exc("Error evaluating factor",
#     552                                  self,
#     553                                  memorize_state["eval_env"].eval,
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# ~/anaconda3/lib/python3.9/site-packages/patsy/compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'numeric_sex' is not defined
#     numeric_sex ~ flipper_length_mm + bill_length_mm + bill_depth_mm + C(island)
#     ^^^^^^^^^^^

# %% [markdown]
# ## Exploración de nuestras variables categóricas

# %%
#Tabla de conteo de las variables categoricas isla y sexo
(
    processed_penguins_df
    .value_counts(['island', 'sex'])
    .reset_index(name='count')
)
# Out:
#       island     sex  count
# 0     Biscoe    male     83
# 1     Biscoe  female     80
# 2      Dream    male     62
# 3      Dream  female     61
# 4  Torgersen  female     24
# 5  Torgersen    male     23

# %% [markdown]
# ## ¿Podemos definir un modelo que nos ayude a identificar si un pingüino pertenece a determinada clase?

# %%
processed_penguins_df = (
    processed_penguins_df
    .assign(is_adelie=lambda df: df.species.replace(['Adelie', 'Gentoo', 'Chinstrap'], [1,0,0]))
)

# %%
#Modelo para determinar si un pinguino es adelie segun su sexo y el largo de las aletas
model_is_adele = smf.logit(
    formula='is_adelie ~ flipper_length_mm + C(sex)',
    data=processed_penguins_df
).fit()

model_is_adele.params #muestra solo los parametros del modelo
# Out:
# Optimization terminated successfully.
#          Current function value: 0.355225
#          Iterations 8
# Intercept            40.568368
# C(sex)[T.male]        1.282656
# flipper_length_mm    -0.209705
# dtype: float64

# %%
is_adelie_df_prediction = pd.DataFrame(
    dict(
        actual_adelie = processed_penguins_df.is_adelie,
        predicted_values = model_is_adele.predict().round()  #round indica solo si es cero o uno
    )
)

is_adelie_df_prediction
# Out:
#      actual_adelie  predicted_values
# 0                1               1.0
# 1                1               1.0
# 2                1               0.0
# 4                1               1.0
# 5                1               1.0
# ..             ...               ...
# 339              0               0.0
# 340              0               0.0
# 341              0               1.0
# 342              0               0.0
# 343              0               0.0
#
# [333 rows x 2 columns]

# %%
(
    is_adelie_df_prediction
    .value_counts(['actual_adelie', 'predicted_values'])
    .reset_index(name='count')
)
# Out:
#    actual_adelie  predicted_values  count
# 0              0               0.0    151
# 1              1               1.0    129
# 2              0               1.0     36
# 3              1               0.0     17

# %%
print(
    sklearn.metrics.confusion_matrix(
        is_adelie_df_prediction.actual_adelie,
        is_adelie_df_prediction.predicted_values
    )
)

sklearn.metrics.accuracy_score(
    is_adelie_df_prediction.actual_adelie,
    is_adelie_df_prediction.predicted_values
)
# Out:
# [[151  36]
#  [ 17 129]]
# 0.8408408408408409

# %% [markdown]
# # Paradoja de Simpson

# %%
#Exploracion visual de los datos con seaborn
sns.pairplot(
    data=processed_penguins_df,
    hue='species',
    palette=penguin_color
)

# %% [markdown]
# ## Información de sesión

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# empiricaldist       NA
# janitor             0.23.1
# matplotlib          3.6.0
# numpy               1.23.4
# palmerpenguins      0.1.4
# pandas              1.5.1
# scipy               1.9.3
# seaborn             0.12.1
# session_info        1.0.0
# sklearn             1.1.2
# statsmodels         0.13.5
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         9.3.0
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.5
# cffi                        1.15.1
# cloudpickle                 2.0.0
# colorama                    0.4.6
# comm                        0.1.2
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.12.0
# dask                        2022.02.1
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# hypergeom_ufunc             NA
# importlib_metadata          NA
# ipykernel                   6.19.2
# ipython_genutils            0.2.0
# ipywidgets                  7.6.5
# jedi                        0.18.1
# jinja2                      2.11.3
# joblib                      1.1.1
# jupyter_server              1.23.4
# kiwisolver                  1.4.4
# lazy_loader                 NA
# markupsafe                  2.0.1
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# multipledispatch            0.6.0
# natsort                     8.3.1
# nbinom_ufunc                NA
# ncf_ufunc                   NA
# numexpr                     2.8.4
# packaging                   22.0
# pandas_flavor               NA
# parso                       0.8.3
# patsy                       0.5.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                2.5.2
# prompt_toolkit              3.0.36
# psutil                      5.9.0
# ptyprocess                  0.7.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.11.2
# pyparsing                   3.0.9
# pytz                        2022.7
# ruamel                      NA
# setuptools                  65.6.3
# six                         1.16.0
# sphinxcontrib               NA
# storemagic                  NA
# tblib                       1.7.0
# threadpoolctl               2.2.0
# tlz                         0.12.0
# toolz                       0.12.0
# tornado                     6.2
# traitlets                   5.7.1
# typing_extensions           NA
# wcwidth                     0.2.5
# xarray                      2022.11.0
# yaml                        6.0
# zipp                        NA
# zmq                         23.2.0
# zoneinfo                    NA
# zope                        NA
# zstandard                   0.18.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             7.31.1
# jupyter_client      7.4.8
# jupyter_core        5.1.1
# jupyterlab          3.5.2
# notebook            6.5.2
# -----
# Python 3.9.16 (main, Jan 11 2023, 16:05:54) [GCC 11.2.0]
# Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# -----
# Session information updated at 2023-03-09 16:05
# </pre>
# </details>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c6b21ff0-a2d8-42c1-a3af-bd7128045a6d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
